# %%
# %%capture
# !pip install nltk
# !pip install spacy==2.3.5
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz

# %%
from pyresparser import ResumeParser
data = ResumeParser('/content/drive/MyDrive/Colab/AI_project/resume.pdf').get_extracted_data()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-5a4f0d75c11f> in <module>
#       1 from pyresparser import ResumeParser
# ----> 2 data = ResumeParser('/content/drive/MyDrive/Colab/AI_project/resume.pdf').get_extracted_data()
#
# /usr/local/lib/python3.8/dist-packages/pyresparser/resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      18         custom_regex=None
#      19     ):
# ---> 20         nlp = spacy.load('en_core_web_sm')
#      21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#
# /usr/local/lib/python3.8/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#
# /usr/local/lib/python3.8/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
# ...

# %%
# %%capture
# spaCy
# !python -m spacy download en_core_web_sm

# nltk
# !python -m nltk.downloader stopwords
# !python -m nltk.downloader punkt
# !python -m nltk.downloader averaged_perceptron_tagger
# !python -m nltk.downloader universal_tagset
# !python -m nltk.downloader wordnet
# !python -m nltk.downloader brown
# !python -m nltk.downloader maxent_ne_chunker

# %%
# %%capture
# !pip install pyresparser
# !python -m spacy validate

# %%
from pyresparser import ResumeParser
data = ResumeParser('/content/drive/MyDrive/Colab/AI_project/resume.pdf').get_extracted_data()

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
stopw  = set(stopwords.words('english'))
df =pd.read_csv('https://raw.githubusercontent.com/pik1989/HRAnalytics-Project/main/job_final.csv') 
df
# Out:
#       Unnamed: 0                                                url  \
# 0              0  https://www.glassdoor.co.in/partner/jobListing...
# 1              1  https://www.glassdoor.co.in/partner/jobListing...
# 2              2  https://www.glassdoor.co.in/partner/jobListing...
# 3              3  https://www.glassdoor.co.in/partner/jobListing...
# 4              4  https://www.glassdoor.co.in/partner/jobListing...
# ...          ...                                                ...
# 1919        3113  https://www.glassdoor.co.in/partner/jobListing...
# 1920        3115  https://www.glassdoor.co.in/partner/jobListing...
# 1921        3120  https://www.glassdoor.co.in/partner/jobListing...
# 1922        3122  https://www.glassdoor.co.in/partner/jobListing...
# 1923        3123  https://www.glassdoor.co.in/partner/jobListing...
#
#                                                Position  \
# 0                           Software Testing Internship
# ...
